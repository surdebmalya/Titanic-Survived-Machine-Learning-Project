# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline
import math

# %% [markdown]
# # **Collecting Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
titanic_data=pd.read_csv('/content/drive/My Drive/ML CSVs/titanic_dataset.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# # **Analyzing Data**

# %%
sns.countplot(x='Survived',data=titanic_data)

# %%
sns.countplot(x='Survived',hue='Sex',data=titanic_data)

# %%
sns.countplot(x='Survived',hue='Pclass',data=titanic_data)

# %%
titanic_data['Age'].plot.hist()

# %%
titanic_data['Fare'].plot.hist(bins=20,figsize=(10,5))
#bins->for width of each plot of histogram
#figsize->makes the picture to that size

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.countplot(x='SibSp',data=titanic_data)

# %% [markdown]
# # **Data Wrangling**

# %%
titanic_data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False  False     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False  False     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 886        False     False   False  False  ...   False  False   True     False
# 887        False     False   False  False  ...   False  False  False     False
# 888        False     False   False  False  ...   False  False   True     False
# 889        False     False   False  False  ...   False  False  False     False
# 890        False     False   False  False  ...   False  False   True     False
#
# [891 rows x 12 columns]

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(titanic_data.isnull(),yticklabels=False)

# %%
sns.heatmap(titanic_data.isnull(),yticklabels=False,cmap='viridis')

# %%
sns.boxplot(x='Pclass',y='Age',data=titanic_data)

# %% [markdown]
# This plot concludes that, passengers travelling class 1 or class 2 are tending to older than the passengers travelling in class 3

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
titanic_data.drop('Cabin',axis=1,inplace=True)
#it drops the 'Cabin' column

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0            1         0       3  ...         A/5 21171   7.2500         S
# 1            2         1       1  ...          PC 17599  71.2833         C
# 2            3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1       1  ...            113803  53.1000         S
# 4            5         0       3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
titanic_data.dropna(inplace=True)

# %%
sns.heatmap(titanic_data.isnull(),yticklabels=False,cmap='viridis')

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0            1         0       3  ...         A/5 21171   7.2500         S
# 1            2         1       1  ...          PC 17599  71.2833         C
# 2            3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1       1  ...            113803  53.1000         S
# 4            5         0       3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
pd.get_dummies(titanic_data['Sex'])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 885       1     0
# 886       0     1
# 887       1     0
# 889       0     1
# 890       0     1
#
# [712 rows x 2 columns]

# %%
sex=pd.get_dummies(titanic_data['Sex'],drop_first=True)
sex.head()
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
embark=pd.get_dummies(titanic_data['Embarked'],drop_first=True)
embark.head()
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
pcl=pd.get_dummies(titanic_data['Pclass'],drop_first=True)
pcl.head()
# Out:
#    2  3
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  0
# 4  0  1

# %%
titanic_data=pd.concat([titanic_data,sex,embark,pcl],axis=1)
titanic_data
# Out:
#      PassengerId  Survived  Pclass  ...  S  2  3
# 0              1         0       3  ...  1  0  1
# 1              2         1       1  ...  0  0  0
# 2              3         1       3  ...  1  0  1
# 3              4         1       1  ...  1  0  0
# 4              5         0       3  ...  1  0  1
# ..           ...       ...     ...  ... .. .. ..
# 885          886         0       3  ...  0  0  1
# 886          887         0       2  ...  1  1  0
# 887          888         1       1  ...  1  0  0
# 889          890         1       1  ...  0  0  0
# 890          891         0       3  ...  0  0  1
#
# [712 rows x 16 columns]

# %% [markdown]
# For Logistic Regressio , we can't do anything with String values, so drop those columns

# %%
titanic_data.drop(['PassengerId','Name','Sex','Embarked','Pclass','Ticket'],axis=1,inplace=True)

# %%
titanic_data
# Out:
#      Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0           0  22.0      1      0   7.2500     1  0  1  0  1
# 1           1  38.0      1      0  71.2833     0  0  0  0  0
# 2           1  26.0      0      0   7.9250     0  0  1  0  1
# 3           1  35.0      1      0  53.1000     0  0  1  0  0
# 4           0  35.0      0      0   8.0500     1  0  1  0  1
# ..        ...   ...    ...    ...      ...   ... .. .. .. ..
# 885         0  39.0      0      5  29.1250     0  1  0  0  1
# 886         0  27.0      0      0  13.0000     1  0  1  1  0
# 887         1  19.0      0      0  30.0000     0  0  1  0  0
# 889         1  26.0      0      0  30.0000     1  0  0  0  0
# 890         0  32.0      0      0   7.7500     1  1  0  0  1
#
# [712 rows x 10 columns]

# %% [markdown]
# # **Train & Test Data**

# %%
X=titanic_data.drop('Survived',axis=1) #X->independent variable
y=titanic_data['Survived'] #y->dependent variable

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logmodel=LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions=logmodel.predict(X_test)

# %% [markdown]
# # **Accuracy Checking**

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 0.4686429005376045

# %%
from sklearn.metrics import classification_report
classification_report(y_test,predictions)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.79      0.86      0.82       125\n           1       0.77      0.67      0.72        89\n\n    accuracy                           0.78       214\n   macro avg       0.78      0.77      0.77       214\nweighted avg       0.78      0.78      0.78       214\n'

# %%
from sklearn.metrics import confusion_matrix  ##   CM      predicted_No   predicted_Yes
confusion_matrix(y_test,predictions)          ##Actual_No      107            18
                                              ##Acutal_Yes      29            60
# Out:
# array([[107,  18],
#        [ 29,  60]])

# %%
#Accuracy from confution matrix: (CM[0][0]+CM[1][1])/CM[i][j]
                                                    #For all values of i and j
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predictions)
# Out:
# 0.780373831775701

# %% [markdown]
# # **Conclusion**
#
#
# **The accuracy of the above model is 78.04%, which is quite good for Logistic Regression.**
